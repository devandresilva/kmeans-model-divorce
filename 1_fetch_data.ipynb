# %% [markdown]
# # 1. Installation of libraries

# %%
# !pip install wandb

# %%
import pandas as pd
from google.colab import drive

# %% [markdown]
# # 2. Fetch Data

# %% [markdown]
# ## 2.1 Create raw_data.csv artifact

# %%
#mount drive to import dataset from google drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#load dataset
path = "/content/gdrive/MyDrive/divorce_model/Dataset/"
df = pd.read_csv(path+"divorce_data.csv", sep=';')

# %%
df.head()
# Out:
#    Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8  Q9  Q10  ...  Q46  Q47  Q48  Q49  Q50  Q51  \
# 0   2   2   4   1   0   0   0   0   0    0  ...    2    1    3    3    3    2
# 1   4   4   4   4   4   0   0   4   4    4  ...    2    2    3    4    4    4
# 2   2   2   2   2   1   3   2   1   1    2  ...    3    2    3    1    1    1
# 3   3   2   3   2   3   3   3   3   3    3  ...    2    2    3    3    3    3
# 4   2   2   1   1   1   1   0   0   0    0  ...    2    1    2    3    2    2
#
#    Q52  Q53  Q54  Divorce
# 0    3    2    1        1
# 1    4    2    2        1
# 2    2    2    2        1
# 3    2    2    2        1
# 4    2    1    0        1
#
# [5 rows x 55 columns]

# %%
#export dataframe as raw_data
df.to_csv("raw_data.csv", index=False)

# %% [markdown]
# ## 2.2 Exportind raw_data.csv artifact to wandb

# %%
# !wandb login --relogin
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
#send the raw_data.csv to the wandb storing it as an artifact
# !wandb artifact put \
      --name divorce_kmeans/raw_data.csv \
      --type raw_data \
      --description "The raw data from divorce dataset" raw_data.csv
# Out:
# wandb: Uploading file raw_data.csv to: "andre-silva1ifrn/divorce_kmeans/raw_data.csv:latest" (raw_data)
# wandb: Currently logged in as: andre-silva1ifrn. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /content/wandb/run-20231122_183514-83a1s09m
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run fearless-shape-3
# wandb: ⭐️ View project at https://wandb.ai/andre-silva1ifrn/divorce_kmeans
# wandb: 🚀 View run at https://wandb.ai/andre-silva1ifrn/divorce_kmeans/runs/83a1s09m
# Artifact uploaded, use this artifact in a run by adding:
#
#     artifact = run.use_artifact("andre-silva1ifrn/divorce_kmeans/raw_data.csv:v0")
#
# wandb: 🚀 View run fearless-shape-3 at: https://wandb.ai/andre-silva1ifrn/divorce_kmeans/runs/83a1s09m
# wandb: Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231122_183514-83a1s09m/logs
